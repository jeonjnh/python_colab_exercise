# %% [markdown]
# <a href="https://colab.research.google.com/github/jeonjnh/python_colab_exercise/blob/main/Python_Pandas_Nodo_1_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %% [markdown]
# # 1. Series
# 1차원 데이터(정수, 실수, 문자열 등)
#
# Series 객체생성
# 예) 1월부터 4월까지 평균온도 데이터(-20,-10,10,20)

# %%
temp = pd.Series([-20,-10,10,20])
temp
# Out:
# 0   -20
# 1   -10
# 2    10
# 3    20
# dtype: int64

# %%
temp[0]
# Out:
# -20

# %% [markdown]
# Series 객체생성 (index 지정)

# %%
temp = pd.Series([-20,-10,10,20], index=['Jan','Feb','Mar','Apr'])
temp
# Out:
# Jan   -20
# Feb   -10
# Mar    10
# Apr    20
# dtype: int64

# %%
temp['Jan']
# Out:
# -20

# %% [markdown]
# # 2.Data Frame
# 2차원 데이터(Series 들의 모음)

# %% [markdown]
# ## Data preparation

# %%
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}
data
# Out:
# {'이름': ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
#  '학교': ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
#  '키': [197, 184, 168, 187, 188, 202, 188, 190],
#  '국어': [90, 40, 80, 40, 15, 80, 55, 100],
#  '영어': [85, 35, 75, 60, 20, 100, 65, 85],
#  '수학': [100, 50, 70, 70, 10, 95, 45, 90],
#  '과학': [95, 55, 80, 75, 35, 85, 40, 95],
#  '사회': [85, 25, 75, 80, 10, 80, 35, 95],
#  'SW특기': ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']}

# %%
data['이름']
# Out:
# ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협']

# %%
data['키']
# Out:
# [197, 184, 168, 187, 188, 202, 188, 190]

# %% [markdown]
# ## Data Frame Class

# %%
df = pd.DataFrame(data)
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ## data access

# %%
df['이름']
# Out:
# 0    채치수
# 1    정대만
# 2    송태섭
# 3    서태웅
# 4    강백호
# 5    변덕규
# 6    황태산
# 7    윤대협
# Name: 이름, dtype: object

# %%
df['키']
# Out:
# 0    197
# 1    184
# 2    168
# 3    187
# 4    188
# 5    202
# 6    188
# 7    190
# Name: 키, dtype: int64

# %%
df[['이름','키']]
# Out:
#     이름    키
# 0  채치수  197
# 1  정대만  184
# 2  송태섭  168
# 3  서태웅  187
# 4  강백호  188
# 5  변덕규  202
# 6  황태산  188
# 7  윤대협  190

# %% [markdown]
# ## DataFrame Class with Index

# %%
df = pd.DataFrame(data, index=['No.1','No.2','No.3','No.4','No.5','No.6','No.7','No.8'])
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# No.1  채치수  북산고  197   90   85  100  95  85      Python
# No.2  정대만  북산고  184   40   35   50  55  25        Java
# No.3  송태섭  북산고  168   80   75   70  80  75  Javascript
# No.4  서태웅  북산고  187   40   60   70  75  80
# No.5  강백호  북산고  188   15   20   10  35  10
# No.6  변덕규  능남고  202   80  100   95  85  80           C
# No.7  황태산  능남고  188   55   65   45  40  35      PYTHON
# No.8  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ## DataFrame Class with selected column

# %%
df = pd.DataFrame(data, columns=['이름','학교','키'])
df
# Out:
#     이름   학교    키
# 0  채치수  북산고  197
# 1  정대만  북산고  184
# 2  송태섭  북산고  168
# 3  서태웅  북산고  187
# 4  강백호  북산고  188
# 5  변덕규  능남고  202
# 6  황태산  능남고  188
# 7  윤대협  능남고  190

# %% [markdown]
# # 3. Index
# 데이터에 접근할 수 있는 주소값

# %%
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}

df = pd.DataFrame(data, index=['No.1','No.2','No.3','No.4','No.5','No.6','No.7','No.8'])
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# No.1  채치수  북산고  197   90   85  100  95  85      Python
# No.2  정대만  북산고  184   40   35   50  55  25        Java
# No.3  송태섭  북산고  168   80   75   70  80  75  Javascript
# No.4  서태웅  북산고  187   40   60   70  75  80
# No.5  강백호  북산고  188   15   20   10  35  10
# No.6  변덕규  능남고  202   80  100   95  85  80           C
# No.7  황태산  능남고  188   55   65   45  40  35      PYTHON
# No.8  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.index
# Out:
# Index(['No.1', 'No.2', 'No.3', 'No.4', 'No.5', 'No.6', 'No.7', 'No.8'], dtype='object')

# %% [markdown]
# ## index name

# %%
df.index.name = 'No. of application'
df
# Out:
#                      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# No. of application
# No.1                채치수  북산고  197   90   85  100  95  85      Python
# No.2                정대만  북산고  184   40   35   50  55  25        Java
# No.3                송태섭  북산고  168   80   75   70  80  75  Javascript
# No.4                서태웅  북산고  187   40   60   70  75  80
# No.5                강백호  북산고  188   15   20   10  35  10
# No.6                변덕규  능남고  202   80  100   95  85  80           C
# No.7                황태산  능남고  188   55   65   45  40  35      PYTHON
# No.8                윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ## index initialization

# %%
df.reset_index()
# Out:
#   No. of application   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0               No.1  채치수  북산고  197   90   85  100  95  85      Python
# 1               No.2  정대만  북산고  184   40   35   50  55  25        Java
# 2               No.3  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3               No.4  서태웅  북산고  187   40   60   70  75  80
# 4               No.5  강백호  북산고  188   15   20   10  35  10
# 5               No.6  변덕규  능남고  202   80  100   95  85  80           C
# 6               No.7  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7               No.8  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.reset_index(drop=True)
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df
# Out:
#                      이름   학교    키   국어   영어   수학  과학  사회        SW특기
# No. of application
# No.1                채치수  북산고  197   90   85  100  95  85      Python
# No.2                정대만  북산고  184   40   35   50  55  25        Java
# No.3                송태섭  북산고  168   80   75   70  80  75  Javascript
# No.4                서태웅  북산고  187   40   60   70  75  80
# No.5                강백호  북산고  188   15   20   10  35  10
# No.6                변덕규  능남고  202   80  100   95  85  80           C
# No.7                황태산  능남고  188   55   65   45  40  35      PYTHON
# No.8                윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.reset_index(drop=True, inplace=True)

# %%
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ## index setting
# 지정한 column으로 index 설정

# %%
df.set_index('이름')
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 채치수  북산고  197   90   85  100  95  85      Python
# 정대만  북산고  184   40   35   50  55  25        Java
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 서태웅  북산고  187   40   60   70  75  80
# 강백호  북산고  188   15   20   10  35  10
# 변덕규  능남고  202   80  100   95  85  80           C
# 황태산  능남고  188   55   65   45  40  35      PYTHON
# 윤대협  능남고  190  100   85   90  95  95          C#

# %%
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80
# 4  강백호  북산고  188   15   20   10  35  10
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.set_index('이름', inplace=True)
df
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 채치수  북산고  197   90   85  100  95  85      Python
# 정대만  북산고  184   40   35   50  55  25        Java
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 서태웅  북산고  187   40   60   70  75  80
# 강백호  북산고  188   15   20   10  35  10
# 변덕규  능남고  202   80  100   95  85  80           C
# 황태산  능남고  188   55   65   45  40  35      PYTHON
# 윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ## index sorting

# %%
df.sort_index()
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 강백호  북산고  188   15   20   10  35  10
# 변덕규  능남고  202   80  100   95  85  80           C
# 서태웅  북산고  187   40   60   70  75  80
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 윤대협  능남고  190  100   85   90  95  95          C#
# 정대만  북산고  184   40   35   50  55  25        Java
# 채치수  북산고  197   90   85  100  95  85      Python
# 황태산  능남고  188   55   65   45  40  35      PYTHON

# %%
df.sort_index(ascending=False)
# Out:
#       학교    키   국어   영어   수학  과학  사회        SW특기
# 이름
# 황태산  능남고  188   55   65   45  40  35      PYTHON
# 채치수  북산고  197   90   85  100  95  85      Python
# 정대만  북산고  184   40   35   50  55  25        Java
# 윤대협  능남고  190  100   85   90  95  95          C#
# 송태섭  북산고  168   80   75   70  80  75  Javascript
# 서태웅  북산고  187   40   60   70  75  80
# 변덕규  능남고  202   80  100   95  85  80           C
# 강백호  북산고  188   15   20   10  35  10

# %% [markdown]
# # 4. File open and Save
# DataFrame 객체를 excel, csv, txt 등 형태의 파일로 저장 및 열기

# %%
data = {
    '이름' : ['채치수', '정대만', '송태섭', '서태웅', '강백호', '변덕규', '황태산', '윤대협'],
    '학교' : ['북산고', '북산고', '북산고', '북산고', '북산고', '능남고', '능남고', '능남고'],
    '키' : [197, 184, 168, 187, 188, 202, 188, 190],
    '국어' : [90, 40, 80, 40, 15, 80, 55, 100],
    '영어' : [85, 35, 75, 60, 20, 100, 65, 85],
    '수학' : [100, 50, 70, 70, 10, 95, 45, 90],
    '과학' : [95, 55, 80, 75, 35, 85, 40, 95],
    '사회' : [85, 25, 75, 80, 10, 80, 35, 95],
    'SW특기' : ['Python', 'Java', 'Javascript', '', '', 'C', 'PYTHON', 'C#']
}

df = pd.DataFrame(data, index=['No.1','No.2','No.3','No.4','No.5','No.6','No.7','No.8'])
df.index.name = '지원번호'
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# No.1  채치수  북산고  197   90   85  100  95  85      Python
# No.2  정대만  북산고  184   40   35   50  55  25        Java
# No.3  송태섭  북산고  168   80   75   70  80  75  Javascript
# No.4  서태웅  북산고  187   40   60   70  75  80
# No.5  강백호  북산고  188   15   20   10  35  10
# No.6  변덕규  능남고  202   80  100   95  85  80           C
# No.7  황태산  능남고  188   55   65   45  40  35      PYTHON
# No.8  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ## File save
# ### csv file format

# %%
df.to_csv('score.csv', encoding='utf-8-sig')

# %%
df.to_csv('score.csv', encoding='utf-8-sig', index=False)

# %% [markdown]
# ### text file format

# %%
df.to_csv('score.txt', sep='\t')

# %% [markdown]
# ### excel file format

# %%
df.to_excel('score.xlsx')

# %% [markdown]
# ## File Open

# %% [markdown]
# ### csv file open

# %%
df = pd.read_csv('/content/score.csv')
df
# Out:
#     이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197   90   85  100  95  85      Python
# 1  정대만  북산고  184   40   35   50  55  25        Java
# 2  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  서태웅  북산고  187   40   60   70  75  80         NaN
# 4  강백호  북산고  188   15   20   10  35  10         NaN
# 5  변덕규  능남고  202   80  100   95  85  80           C
# 6  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df = pd.read_csv('/content/score.csv', skiprows=1)
df
# Out:
#    채치수  북산고  197   90   85  100  95  85.1      Python
# 0  정대만  북산고  184   40   35   50  55    25        Java
# 1  송태섭  북산고  168   80   75   70  80    75  Javascript
# 2  서태웅  북산고  187   40   60   70  75    80         NaN
# 3  강백호  북산고  188   15   20   10  35    10         NaN
# 4  변덕규  능남고  202   80  100   95  85    80           C
# 5  황태산  능남고  188   55   65   45  40    35      PYTHON
# 6  윤대협  능남고  190  100   85   90  95    95          C#

# %%
df = pd.read_csv('/content/score.csv', skiprows=[1,3,5]) # exclude 1,3,5 rows
df
# Out:
#     이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 0  정대만  북산고  184   40   35  50  55  25    Java
# 1  서태웅  북산고  187   40   60  70  75  80     NaN
# 2  변덕규  능남고  202   80  100  95  85  80       C
# 3  황태산  능남고  188   55   65  45  40  35  PYTHON
# 4  윤대협  능남고  190  100   85  90  95  95      C#

# %%
df = pd.read_csv('/content/score.csv', nrows=4) 
df
# Out:
#     이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 0  채치수  북산고  197  90  85  100  95  85      Python
# 1  정대만  북산고  184  40  35   50  55  25        Java
# 2  송태섭  북산고  168  80  75   70  80  75  Javascript
# 3  서태웅  북산고  187  40  60   70  75  80         NaN

# %%
df = pd.read_csv('/content/score.csv', skiprows=2, nrows=4)
df
# Out:
#    정대만  북산고  184  40   35  50  55  25        Java
# 0  송태섭  북산고  168  80   75  70  80  75  Javascript
# 1  서태웅  북산고  187  40   60  70  75  80         NaN
# 2  강백호  북산고  188  15   20  10  35  10         NaN
# 3  변덕규  능남고  202  80  100  95  85  80           C

# %% [markdown]
# ### text file open

# %%
df = pd.read_csv('/content/score.txt', sep='\t')
df
# Out:
#    지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  No.1  채치수  북산고  197   90   85  100  95  85      Python
# 1  No.2  정대만  북산고  184   40   35   50  55  25        Java
# 2  No.3  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  No.4  서태웅  북산고  187   40   60   70  75  80         NaN
# 4  No.5  강백호  북산고  188   15   20   10  35  10         NaN
# 5  No.6  변덕규  능남고  202   80  100   95  85  80           C
# 6  No.7  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  No.8  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df = pd.read_csv('/content/score.txt', sep='\t', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# No.1  채치수  북산고  197   90   85  100  95  85      Python
# No.2  정대만  북산고  184   40   35   50  55  25        Java
# No.3  송태섭  북산고  168   80   75   70  80  75  Javascript
# No.4  서태웅  북산고  187   40   60   70  75  80         NaN
# No.5  강백호  북산고  188   15   20   10  35  10         NaN
# No.6  변덕규  능남고  202   80  100   95  85  80           C
# No.7  황태산  능남고  188   55   65   45  40  35      PYTHON
# No.8  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df = pd.read_csv('/content/score.txt', sep='\t')
df.set_index('지원번호', inplace=True)
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# No.1  채치수  북산고  197   90   85  100  95  85      Python
# No.2  정대만  북산고  184   40   35   50  55  25        Java
# No.3  송태섭  북산고  168   80   75   70  80  75  Javascript
# No.4  서태웅  북산고  187   40   60   70  75  80         NaN
# No.5  강백호  북산고  188   15   20   10  35  10         NaN
# No.6  변덕규  능남고  202   80  100   95  85  80           C
# No.7  황태산  능남고  188   55   65   45  40  35      PYTHON
# No.8  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ### excel file open

# %%
df = pd.read_excel('/content/score.xlsx')
df
# Out:
#    지원번호   이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 0  No.1  채치수  북산고  197   90   85  100  95  85      Python
# 1  No.2  정대만  북산고  184   40   35   50  55  25        Java
# 2  No.3  송태섭  북산고  168   80   75   70  80  75  Javascript
# 3  No.4  서태웅  북산고  187   40   60   70  75  80         NaN
# 4  No.5  강백호  북산고  188   15   20   10  35  10         NaN
# 5  No.6  변덕규  능남고  202   80  100   95  85  80           C
# 6  No.7  황태산  능남고  188   55   65   45  40  35      PYTHON
# 7  No.8  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# # 5. Data Check

# %%
df = pd.read_excel('/content/score.xlsx', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# No.1  채치수  북산고  197   90   85  100  95  85      Python
# No.2  정대만  북산고  184   40   35   50  55  25        Java
# No.3  송태섭  북산고  168   80   75   70  80  75  Javascript
# No.4  서태웅  북산고  187   40   60   70  75  80         NaN
# No.5  강백호  북산고  188   15   20   10  35  10         NaN
# No.6  변덕규  능남고  202   80  100   95  85  80           C
# No.7  황태산  능남고  188   55   65   45  40  35      PYTHON
# No.8  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ## DataFrame check

# %%
df.describe()
# Out:
#                 키          국어          영어          수학         과학         사회
# count    8.000000    8.000000    8.000000    8.000000   8.000000   8.000000
# mean   188.000000   62.500000   65.625000   66.250000  70.000000  60.625000
# std      9.985704   29.519969   26.917533   30.325614  23.754699  32.120032
# min    168.000000   15.000000   20.000000   10.000000  35.000000  10.000000
# 25%    186.250000   40.000000   53.750000   48.750000  51.250000  32.500000
# 50%    188.000000   67.500000   70.000000   70.000000  77.500000  77.500000
# 75%    191.750000   82.500000   85.000000   91.250000  87.500000  81.250000
# max    202.000000  100.000000  100.000000  100.000000  95.000000  95.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, No.1 to No.8
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   이름      8 non-null      object
#  1   학교      8 non-null      object
#  2   키       8 non-null      int64
#  3   국어      8 non-null      int64
#  4   영어      8 non-null      int64
#  5   수학      8 non-null      int64
#  6   과학      8 non-null      int64
#  7   사회      8 non-null      int64
#  8   SW특기    6 non-null      object
# dtypes: int64(6), object(3)
# memory usage: 940.0+ bytes

# %%
df.head()
# Out:
#        이름   학교    키  국어  영어   수학  과학  사회        SW특기
# 지원번호
# No.1  채치수  북산고  197  90  85  100  95  85      Python
# No.2  정대만  북산고  184  40  35   50  55  25        Java
# No.3  송태섭  북산고  168  80  75   70  80  75  Javascript
# No.4  서태웅  북산고  187  40  60   70  75  80         NaN
# No.5  강백호  북산고  188  15  20   10  35  10         NaN

# %%
df.head(7)
# Out:
#        이름   학교    키  국어   영어   수학  과학  사회        SW특기
# 지원번호
# No.1  채치수  북산고  197  90   85  100  95  85      Python
# No.2  정대만  북산고  184  40   35   50  55  25        Java
# No.3  송태섭  북산고  168  80   75   70  80  75  Javascript
# No.4  서태웅  북산고  187  40   60   70  75  80         NaN
# No.5  강백호  북산고  188  15   20   10  35  10         NaN
# No.6  변덕규  능남고  202  80  100   95  85  80           C
# No.7  황태산  능남고  188  55   65   45  40  35      PYTHON

# %%
df.tail()
# Out:
#        이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 지원번호
# No.4  서태웅  북산고  187   40   60  70  75  80     NaN
# No.5  강백호  북산고  188   15   20  10  35  10     NaN
# No.6  변덕규  능남고  202   80  100  95  85  80       C
# No.7  황태산  능남고  188   55   65  45  40  35  PYTHON
# No.8  윤대협  능남고  190  100   85  90  95  95      C#

# %%
df.values
# Out:
# array([['채치수', '북산고', 197, 90, 85, 100, 95, 85, 'Python'],
#        ['정대만', '북산고', 184, 40, 35, 50, 55, 25, 'Java'],
#        ['송태섭', '북산고', 168, 80, 75, 70, 80, 75, 'Javascript'],
#        ['서태웅', '북산고', 187, 40, 60, 70, 75, 80, nan],
#        ['강백호', '북산고', 188, 15, 20, 10, 35, 10, nan],
#        ['변덕규', '능남고', 202, 80, 100, 95, 85, 80, 'C'],
#        ['황태산', '능남고', 188, 55, 65, 45, 40, 35, 'PYTHON'],
#        ['윤대협', '능남고', 190, 100, 85, 90, 95, 95, 'C#']], dtype=object)

# %%
df.index
# Out:
# Index(['No.1', 'No.2', 'No.3', 'No.4', 'No.5', 'No.6', 'No.7', 'No.8'], dtype='object', name='지원번호')

# %%
df.columns
# Out:
# Index(['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기'], dtype='object')

# %%
df.shape # (row, column)
# Out:
# (8, 9)

# %% [markdown]
# ## Series Check

# %%
df['키'].describe()
# Out:
# count      8.000000
# mean     188.000000
# std        9.985704
# min      168.000000
# 25%      186.250000
# 50%      188.000000
# 75%      191.750000
# max      202.000000
# Name: 키, dtype: float64

# %%
df['키'].min()
# Out:
# 168

# %%
df['키'].max()
# Out:
# 202

# %%
df['키'].nlargest(3)
# Out:
# 지원번호
# No.6    202
# No.1    197
# No.8    190
# Name: 키, dtype: int64

# %%
df['키'].mean()
# Out:
# 188.0

# %%
df['키'].sum()
# Out:
# 1504

# %%
df['SW특기'].count()
# Out:
# 6

# %%
df['학교'].unique()
# Out:
# array(['북산고', '능남고'], dtype=object)

# %%
df['학교'].nunique()
# Out:
# 2

# %% [markdown]
# # 6. Data Selection (Basic)

# %%
df = pd.read_excel('/content/score.xlsx', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# No.1  채치수  북산고  197   90   85  100  95  85      Python
# No.2  정대만  북산고  184   40   35   50  55  25        Java
# No.3  송태섭  북산고  168   80   75   70  80  75  Javascript
# No.4  서태웅  북산고  187   40   60   70  75  80         NaN
# No.5  강백호  북산고  188   15   20   10  35  10         NaN
# No.6  변덕규  능남고  202   80  100   95  85  80           C
# No.7  황태산  능남고  188   55   65   45  40  35      PYTHON
# No.8  윤대협  능남고  190  100   85   90  95  95          C#

# %% [markdown]
# ## Column selection (label)

# %%
df[['이름', '키']]
# Out:
#        이름    키
# 지원번호
# No.1  채치수  197
# No.2  정대만  184
# No.3  송태섭  168
# No.4  서태웅  187
# No.5  강백호  188
# No.6  변덕규  202
# No.7  황태산  188
# No.8  윤대협  190

# %% [markdown]
# ### Column selection (index)

# %%
df.columns
# Out:
# Index(['이름', '학교', '키', '국어', '영어', '수학', '과학', '사회', 'SW특기'], dtype='object')

# %%
df.columns[0]
# Out:
# '이름'

# %%
df.columns[2]
# Out:
# '키'

# %%
df[df.columns[0]]
# Out:
# 지원번호
# No.1    채치수
# No.2    정대만
# No.3    송태섭
# No.4    서태웅
# No.5    강백호
# No.6    변덕규
# No.7    황태산
# No.8    윤대협
# Name: 이름, dtype: object

# %%
df[df.columns[-1]]
# Out:
# 지원번호
# No.1        Python
# No.2          Java
# No.3    Javascript
# No.4           NaN
# No.5           NaN
# No.6             C
# No.7        PYTHON
# No.8            C#
# Name: SW특기, dtype: object

# %% [markdown]
# ### Slicing

# %%
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# No.1  채치수  북산고  197   90   85  100  95  85      Python
# No.2  정대만  북산고  184   40   35   50  55  25        Java
# No.3  송태섭  북산고  168   80   75   70  80  75  Javascript
# No.4  서태웅  북산고  187   40   60   70  75  80         NaN
# No.5  강백호  북산고  188   15   20   10  35  10         NaN
# No.6  변덕규  능남고  202   80  100   95  85  80           C
# No.7  황태산  능남고  188   55   65   45  40  35      PYTHON
# No.8  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df['영어'][0:5]
# Out:
# 지원번호
# No.1    85
# No.2    35
# No.3    75
# No.4    60
# No.5    20
# Name: 영어, dtype: int64

# %%
df[['이름', '키']][:3]
# Out:
#        이름    키
# 지원번호
# No.1  채치수  197
# No.2  정대만  184
# No.3  송태섭  168

# %%
df[3:]
# Out:
#        이름   학교    키   국어   영어  수학  과학  사회    SW특기
# 지원번호
# No.4  서태웅  북산고  187   40   60  70  75  80     NaN
# No.5  강백호  북산고  188   15   20  10  35  10     NaN
# No.6  변덕규  능남고  202   80  100  95  85  80       C
# No.7  황태산  능남고  188   55   65  45  40  35  PYTHON
# No.8  윤대협  능남고  190  100   85  90  95  95      C#

# %% [markdown]
# # 7. Data Selection (loc)
# 이름을 이용해서 원하는 row에서 원하는 col 선택

# %%
df = pd.read_excel('/content/score.xlsx', index_col='지원번호')
df
# Out:
#        이름   학교    키   국어   영어   수학  과학  사회        SW특기
# 지원번호
# No.1  채치수  북산고  197   90   85  100  95  85      Python
# No.2  정대만  북산고  184   40   35   50  55  25        Java
# No.3  송태섭  북산고  168   80   75   70  80  75  Javascript
# No.4  서태웅  북산고  187   40   60   70  75  80         NaN
# No.5  강백호  북산고  188   15   20   10  35  10         NaN
# No.6  변덕규  능남고  202   80  100   95  85  80           C
# No.7  황태산  능남고  188   55   65   45  40  35      PYTHON
# No.8  윤대협  능남고  190  100   85   90  95  95          C#

# %%
df.loc['No.1']
# Out:
# 이름         채치수
# 학교         북산고
# 키          197
# 국어          90
# 영어          85
# 수학         100
# 과학          95
# 사회          85
# SW특기    Python
# Name: No.1, dtype: object

# %%
df.loc['No.1', '국어']
# Out:
# 90

# %%
df.loc[['No.1','No.2'], '영어']
# Out:
# 지원번호
# No.1    85
# No.2    35
# Name: 영어, dtype: int64

# %%
df.loc[['No.1','No.2'], ['영어', '수학']]
# Out:
#       영어   수학
# 지원번호
# No.1  85  100
# No.2  35   50

# %%
df.loc['No.1':'No.5', '국어':'사회']
# Out:
#       국어  영어   수학  과학  사회
# 지원번호
# No.1  90  85  100  95  85
# No.2  40  35   50  55  25
# No.3  80  75   70  80  75
# No.4  40  60   70  75  80
# No.5  15  20   10  35  10
